# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_excel('Spotify_data.xlsx')
df.head()
# Out:
#      Age  Gender spotify_usage_period  \
# 0  20-35  Female    More than 2 years
# 1  12-20    Male    More than 2 years
# 2  35-60  Others   6 months to 1 year
# 3  20-35  Female    1 year to 2 years
# 4  20-35  Female    1 year to 2 years
#
#                          spotify_listening_device spotify_subscription_plan  \
# 0              Smart speakers or voice assistants       Free (ad-supported)
# 1                              Computer or laptop       Free (ad-supported)
# 2              Smart speakers or voice assistants       Free (ad-supported)
# 3  Smartphone, Smart speakers or voice assistants       Free (ad-supported)
# 4                                      Smartphone       Free (ad-supported)
#
#   premium_sub_willingness          preffered_premium_plan  \
# 0                     Yes        Family Plan-Rs 179/month
# 1                     Yes  Individual Plan- Rs 119/ month
# 2                     Yes        Student Plan-Rs 59/month
# 3                      No                             NaN
# 4                      No                             NaN
#
#   preferred_listening_content fav_music_genre music_time_slot  \
# 0                     Podcast          Melody           Night
# 1                     Podcast             Rap       Afternoon
# 2                     Podcast             Pop           Night
# 3                       Music          Melody           Night
# 4                       Music          Melody           Night
#
#                                        music_Influencial_mood  \
# 0                                       Sadness or melancholy
# 1                                Social gatherings or parties
# 2                                Relaxation and stress relief
# 3  Relaxation and stress relief, Social gatherings or parties
# 4                                Relaxation and stress relief
#
#                            music_lis_frequency           music_expl_method  \
# 0                                 leisure time                   Playlists
# 1                              Workout session                   Playlists
# 2                 Study Hours, While Traveling                   Playlists
# 3  Office hours, Workout session, leisure time  recommendations, Playlists
# 4                                 leisure time  recommendations, Playlists
#
#    music_recc_rating     pod_lis_frequency         fav_pod_genre  \
# 0                  3                 Daily                Comedy
# 1                  2  Several times a week                Comedy
# 2                  4           Once a week                Sports
# 3                  4                 Never                   NaN
# 4                  4                Rarely  Lifestyle and Health
#
#   preffered_pod_format     pod_host_preference preffered_pod_duration  \
# 0            Interview                    Both                   Both
# 1            Interview                    Both                    NaN
# 2            Interview                     NaN                   Both
# 3                  NaN                     NaN                    NaN
# 4        Story telling  Well known individuals                   Both
#
#   pod_variety_satisfaction
# 0                       Ok
# 1                Satisfied
# 2                Satisfied
# 3                       Ok
# 4                       Ok

# %%
# New columns to be added
num_of_records = len(df)

spotify_listening_device_columns = ['smart speakers', 'voice assistants', 'computer', 'laptop', 'smartphone', 'wearable devices']

influential_mood = ['sadness', 'melancholy', 'social gatherings', 'parties', 'relaxation', 'stress relief', 'uplifting', 'motivational']

music_lis_timing = ['leisure time', 'workout session', 'study hours', 'while traveling', 'office hours', 'social gatherings ', 'night time', 'when cooking', 'random', 'before bed',]

music_exploration_method = ['playlists', 'recommendations', 'others', 'radio', 'social media', 'friends','search']

fav_pod_genre = ['comedy', 'sports', 'lifestyle', 'health', 'business', 'fitness', 'food and cooking', 'everything', 'informative', 'dance', 'technology', 'general knowledge', 'spiritual and devotional', 'finance', 'current affairs', 'murder mystery ', 'political', 'topics that interests me', 'novels', 'self help', 'educational ', 'stories']

# %%
def one_hot_encode_column(dataframe, original_col_name, new_col_names_prefixes, new_col_names, index):
    # Current field inside this columns
    current_value = df.loc[index, original_col_name]
    current_value = current_value.lower().strip()

    for column_name in new_col_names:
      if column_name in current_value: 
         dataframe.loc[index, f"{new_col_names_prefixes}=>{column_name}"] = 1 
      else: 
         dataframe.loc[index, f"{new_col_names_prefixes}=>{column_name}"] = 0 # nans will also be 0
    
    return dataframe

# %%
# Reorganize and one hot encode categorical columns and change nan to 0
for i in range(num_of_records):  
  # Change spotify_listening_device column
  df = one_hot_encode_column(dataframe=df, index=i, original_col_name='spotify_listening_device', 
                             new_col_names_prefixes="listening_device", new_col_names=spotify_listening_device_columns)

  
  # Change music_Influencial_mood column
  df = one_hot_encode_column(dataframe=df, index=i, original_col_name='music_Influencial_mood', 
                             new_col_names_prefixes="influential_mood_music", new_col_names=influential_mood)

  
  # Change music_lis_freq column
  df = one_hot_encode_column(dataframe=df, index=i, original_col_name='music_lis_frequency', 
                             new_col_names_prefixes="music_lis_timing", new_col_names=music_lis_timing)
  
  # Change music_expl_method column
  df = one_hot_encode_column(dataframe=df, index=i, original_col_name='music_expl_method', 
                             new_col_names_prefixes="music_exploration_method", new_col_names=music_exploration_method)
  
  # Change fav_pod_genre column
  record = df.loc[i, 'fav_pod_genre']
  if isinstance(record, float): 
    for column_name in fav_pod_genre:
        df.loc[i, f"fav_pod_genre=>{column_name}"] = 0
  else: 
    record = record.lower()
    for column_name in fav_pod_genre:
      if column_name in record: df.loc[i, f"fav_pod_genre=>{column_name}"] = 1 
      else: df.loc[i, f"fav_pod_genre=>{column_name}"] = 0

# %%
# Drop one hot encoded columns
df = df.drop(columns = ['spotify_listening_device', 'music_Influencial_mood', 'music_lis_frequency', 'music_expl_method', 'fav_pod_genre'], axis = 1)

# %%
# Drop columns that still have nans. Since their nans are  almost half their number of rows
df = df.drop(columns = ['preffered_pod_duration', 'pod_host_preference', 'preffered_pod_format', 'preffered_premium_plan'], axis = 1)

# %%
# Prepare one hot encoded columns
age_dummies = pd.get_dummies(df['Age'], dtype=int, prefix='Age', prefix_sep='=>')
# gender_dummies = pd.get_dummies(df['Gender'], dtype=int, prefix='Gender', prefix_sep='=>')
usage_period_dummies = pd.get_dummies(df['spotify_usage_period'], dtype=int, prefix='spotify_usage_period', prefix_sep='=>')
spotify_subscription_plan_dummies = pd.get_dummies(df['spotify_subscription_plan'], dtype=int, prefix='spotify_subscription_plan', prefix_sep='=>')

preferred_listening_content_dummies = pd.get_dummies(df['preferred_listening_content'], dtype=int, prefix='preferred_listening_content', prefix_sep='=>')
fav_music_genre_dummies = pd.get_dummies(df['fav_music_genre'], dtype=int, prefix='fav_music_genre', prefix_sep='=>')
music_time_slot_dummies = pd.get_dummies(df['music_time_slot'], dtype=int, prefix='music_time_slot', prefix_sep='=>')
pod_lis_frequency_dummies = pd.get_dummies(df['pod_lis_frequency'], dtype=int, prefix='pod_lis_frequency', prefix_sep='=>')

df['premium_sub_willingness'] = df['premium_sub_willingness'].map({'Yes':1, 'No':0})
df['pod_variety_satisfaction'] = df['pod_variety_satisfaction'].map({'Very Dissatisfied': 0, 'Dissatisfied': 1, 'Ok': 2, 'Satisfied': 3, 'Very Satisfied': 4})

# %%
# Remove one hot encoded categorical data
df = df.drop(['Age', 'spotify_usage_period', 'spotify_subscription_plan', 'preferred_listening_content', 'fav_music_genre', 'music_time_slot', 'pod_lis_frequency'] , axis = 1)

# Add new columns to df
df = pd.concat([df,age_dummies, usage_period_dummies, spotify_subscription_plan_dummies, preferred_listening_content_dummies, fav_music_genre_dummies, music_time_slot_dummies, pod_lis_frequency_dummies], axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
label = df['Gender'].map({'Female': 0, 'Male': 1, 'Others': 2})
features = df.drop('Gender', axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, label, test_size = 0.2)

# %%
# Build Logistic Regression Model
from sklearn.linear_model import LogisticRegression
logistic_classifier = LogisticRegression(max_iter = 10000)
logistic_classifier.fit(X_train, y_train)
logistic_classifier_prediction = logistic_classifier.predict(X_test)

# Build Naive Bayes Model
from sklearn.naive_bayes import GaussianNB
naive_bayes_classifier = GaussianNB()
naive_bayes_classifier.fit(X_train, y_train)
naive_bayes_prediction = naive_bayes_classifier.predict(X_test)

# Build Support Vector Machine
from sklearn.svm import SVC
svc = SVC(kernel = 'linear')
svc.fit(X_train, y_train)
svc_prediction = svc.predict(X_test)

# Build Kernel Support Vector Machine Model
from sklearn.svm import SVC
kernel_svc = SVC(kernel = 'rbf') # Radial Base Function
kernel_svc.fit(X_train, y_train)
kernel_svc_prediction = svc.predict(X_test)

# Build K-Nearest Neighbor Model
from sklearn.neighbors import KNeighborsClassifier
kneighbors = KNeighborsClassifier(n_neighbors = 5)
kneighbors.fit(X_train, y_train)
kneighbors_prediction = kneighbors.predict(X_test)

# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
tree_prediction = tree.predict(X_test)

# Random Forest Model
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100)
forest.fit(X_train, y_train)
forest_prediction = forest.predict(X_test)

# %%
# Evaluate Classification Models
from sklearn.metrics import accuracy_score

logistic_accuracy = accuracy_score(y_test, logistic_classifier_prediction)

naive_bayes_accuracy = accuracy_score(y_test, naive_bayes_prediction)

svc_accuracy = accuracy_score(y_test, svc_prediction)

kernel_svc_accuracy = accuracy_score(y_test, kernel_svc_prediction)

kneighbors_accuracy = accuracy_score(y_test, kneighbors_prediction)

tree_accuracy = accuracy_score(y_test, tree_prediction)

forest_accuracy = accuracy_score(y_test, forest_prediction)

print(f"Linear Support Vector Machine Accuracy: {svc_accuracy:.2f}")
print(f"Kernel Support Vector Machine Accuracy: {kernel_svc_accuracy:.2f}")
print(f"Logistic Regression Accuracy:           {logistic_accuracy:.2f}")
print(f"Random Forest Accuracy:                 {forest_accuracy:.2f}")
print(f"K Nearest Neighbors Accuracy:           {kneighbors_accuracy:.2f}")
print(f"Decision Tree Accuracy:                 {tree_accuracy:.2f}")
print(f"Naive Bayes Accuracy:                   {naive_bayes_accuracy:.2f}")
# Out:
# Linear Support Vector Machine Accuracy: 0.80
# Kernel Support Vector Machine Accuracy: 0.80
# Logistic Regression Accuracy:           0.79
# Random Forest Accuracy:                 0.76
# K Nearest Neighbors Accuracy:           0.74
# Decision Tree Accuracy:                 0.65
# Naive Bayes Accuracy:                   0.21

# %%
print(X_train.shape)
# Out:
# (416, 88)

# %%
from keras import Sequential
from keras.layers import Dense, InputLayer
from keras.optimizers import Adam
from keras.metrics import SparseCategoricalAccuracy
from keras.losses import SparseCategoricalCrossentropy

ANN = Sequential([
  InputLayer(shape = (88,)),
  Dense(units=20, activation='relu'),
  Dense(units=10, activation='relu'),
  Dense(units=4, activation='softmax')
])

ANN.compile(optimizer=Adam(), loss= SparseCategoricalCrossentropy(), metrics=[SparseCategoricalAccuracy()])

training_results = ANN.fit(X_train, y_train, epochs=160)
# Out:
# Epoch 1/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6398 - sparse_categorical_accuracy: 0.1213
# Epoch 2/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3734 - sparse_categorical_accuracy: 0.3799
# Epoch 3/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1909 - sparse_categorical_accuracy: 0.5891
# Epoch 4/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0236 - sparse_categorical_accuracy: 0.7319
# Epoch 5/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8586 - sparse_categorical_accuracy: 0.7548
# Epoch 6/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7308 - sparse_categorical_accuracy: 0.7498
# Epoch 7/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7455 - sparse_categorical_accuracy: 0.7148
# Epoch 8/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6553 - sparse_categorical_accuracy: 0.7591
# Epoch 9/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6177 - sparse_categorical_accuracy: 0.7710
# Epoch 10/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5946 - sparse_categorical_accuracy: 0.7825
# Epoch 11/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6299 - sparse_categorical_accuracy: 0.7354
# Epoch 12/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6176 - sparse_categorical_accuracy: 0.7496
# Epoch 13/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6112 - sparse_categorical_accuracy: 0.7482
# Epoch 14/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6060 - sparse_categorical_accuracy: 0.7421
# Epoch 15/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5974 - sparse_categorical_accuracy: 0.7409
# Epoch 16/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6082 - sparse_categorical_accuracy: 0.7278
# Epoch 17/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5499 - sparse_categorical_accuracy: 0.7736
# Epoch 18/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5938 - sparse_categorical_accuracy: 0.7443
# Epoch 19/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5657 - sparse_categorical_accuracy: 0.7561
# Epoch 20/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5504 - sparse_categorical_accuracy: 0.7718
# Epoch 21/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5261 - sparse_categorical_accuracy: 0.7675
# Epoch 22/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5814 - sparse_categorical_accuracy: 0.7413
# Epoch 23/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5355 - sparse_categorical_accuracy: 0.7498
# Epoch 24/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5337 - sparse_categorical_accuracy: 0.7552
# Epoch 25/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4938 - sparse_categorical_accuracy: 0.7870
# Epoch 26/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5072 - sparse_categorical_accuracy: 0.7722
# Epoch 27/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5541 - sparse_categorical_accuracy: 0.7748
# Epoch 28/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4718 - sparse_categorical_accuracy: 0.8087
# Epoch 29/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4831 - sparse_categorical_accuracy: 0.8211
# Epoch 30/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4918 - sparse_categorical_accuracy: 0.7957
# Epoch 31/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 0.4985 - sparse_categorical_accuracy: 0.8072
# Epoch 32/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4428 - sparse_categorical_accuracy: 0.8175
# Epoch 33/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4220 - sparse_categorical_accuracy: 0.8340
# Epoch 34/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4289 - sparse_categorical_accuracy: 0.8294
# Epoch 35/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4247 - sparse_categorical_accuracy: 0.8607
# Epoch 36/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4732 - sparse_categorical_accuracy: 0.8062
# Epoch 37/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4079 - sparse_categorical_accuracy: 0.8409
# Epoch 38/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4502 - sparse_categorical_accuracy: 0.8223
# Epoch 39/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4265 - sparse_categorical_accuracy: 0.8488
# Epoch 40/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4146 - sparse_categorical_accuracy: 0.8328
# Epoch 41/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4055 - sparse_categorical_accuracy: 0.8345
# Epoch 42/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3980 - sparse_categorical_accuracy: 0.8485
# Epoch 43/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3980 - sparse_categorical_accuracy: 0.8594
# Epoch 44/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3755 - sparse_categorical_accuracy: 0.8647
# Epoch 45/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4138 - sparse_categorical_accuracy: 0.8553
# Epoch 46/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3907 - sparse_categorical_accuracy: 0.8597
# Epoch 47/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3935 - sparse_categorical_accuracy: 0.8590
# Epoch 48/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3704 - sparse_categorical_accuracy: 0.8659
# Epoch 49/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3524 - sparse_categorical_accuracy: 0.8773
# Epoch 50/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3617 - sparse_categorical_accuracy: 0.8923
# Epoch 51/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3890 - sparse_categorical_accuracy: 0.8465
# Epoch 52/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8775
# Epoch 53/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3781 - sparse_categorical_accuracy: 0.8626
# Epoch 54/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3469 - sparse_categorical_accuracy: 0.8795
# Epoch 55/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3881 - sparse_categorical_accuracy: 0.8828
# Epoch 56/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3646 - sparse_categorical_accuracy: 0.8826
# Epoch 57/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3271 - sparse_categorical_accuracy: 0.9050
# Epoch 58/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3555 - sparse_categorical_accuracy: 0.8883
# Epoch 59/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3380 - sparse_categorical_accuracy: 0.9009
# Epoch 60/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3309 - sparse_categorical_accuracy: 0.8883
# Epoch 61/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 92us/step - loss: 0.3359 - sparse_categorical_accuracy: 0.8941
# Epoch 62/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3082 - sparse_categorical_accuracy: 0.9159
# Epoch 63/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3542 - sparse_categorical_accuracy: 0.8656
# Epoch 64/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3315 - sparse_categorical_accuracy: 0.8883
# Epoch 65/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3323 - sparse_categorical_accuracy: 0.9028
# Epoch 66/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2846 - sparse_categorical_accuracy: 0.8986
# Epoch 67/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3348 - sparse_categorical_accuracy: 0.8995
# Epoch 68/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3030 - sparse_categorical_accuracy: 0.8912
# Epoch 69/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2650 - sparse_categorical_accuracy: 0.9173
# Epoch 70/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3224 - sparse_categorical_accuracy: 0.8973
# Epoch 71/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2901 - sparse_categorical_accuracy: 0.9110
# Epoch 72/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.2971 - sparse_categorical_accuracy: 0.9046
# Epoch 73/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2911 - sparse_categorical_accuracy: 0.9056
# Epoch 74/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2921 - sparse_categorical_accuracy: 0.9053
# Epoch 75/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804 - sparse_categorical_accuracy: 0.9208
# Epoch 76/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2599 - sparse_categorical_accuracy: 0.9238
# Epoch 77/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2563 - sparse_categorical_accuracy: 0.9226
# Epoch 78/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2569 - sparse_categorical_accuracy: 0.9266
# Epoch 79/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2463 - sparse_categorical_accuracy: 0.9330
# Epoch 80/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2627 - sparse_categorical_accuracy: 0.9262
# Epoch 81/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2472 - sparse_categorical_accuracy: 0.9263
# Epoch 82/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2410 - sparse_categorical_accuracy: 0.9296
# Epoch 83/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2540 - sparse_categorical_accuracy: 0.9203
# Epoch 84/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2183 - sparse_categorical_accuracy: 0.9335
# Epoch 85/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.2793 - sparse_categorical_accuracy: 0.8976
# Epoch 86/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2648 - sparse_categorical_accuracy: 0.9036
# Epoch 87/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2449 - sparse_categorical_accuracy: 0.9267
# Epoch 88/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2076 - sparse_categorical_accuracy: 0.9445
# Epoch 89/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2058 - sparse_categorical_accuracy: 0.9430
# Epoch 90/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2101 - sparse_categorical_accuracy: 0.9307
# Epoch 91/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2235 - sparse_categorical_accuracy: 0.9287
# Epoch 92/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2655 - sparse_categorical_accuracy: 0.9009
# Epoch 93/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1830 - sparse_categorical_accuracy: 0.9470
# Epoch 94/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2164 - sparse_categorical_accuracy: 0.9241
# Epoch 95/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.1991 - sparse_categorical_accuracy: 0.9473
# Epoch 96/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1824 - sparse_categorical_accuracy: 0.9460
# Epoch 97/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1915 - sparse_categorical_accuracy: 0.9432
# Epoch 98/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1809 - sparse_categorical_accuracy: 0.9424
# Epoch 99/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2229 - sparse_categorical_accuracy: 0.9354
# Epoch 100/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2067 - sparse_categorical_accuracy: 0.9315
# Epoch 101/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1830 - sparse_categorical_accuracy: 0.9430
# Epoch 102/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1878 - sparse_categorical_accuracy: 0.9447
# Epoch 103/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1585 - sparse_categorical_accuracy: 0.9546
# Epoch 104/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2010 - sparse_categorical_accuracy: 0.9442
# Epoch 105/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1575 - sparse_categorical_accuracy: 0.9615
# Epoch 106/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1601 - sparse_categorical_accuracy: 0.9554
# Epoch 107/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1564 - sparse_categorical_accuracy: 0.9525
# Epoch 108/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1690 - sparse_categorical_accuracy: 0.9492
# Epoch 109/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1786 - sparse_categorical_accuracy: 0.9390
# Epoch 110/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1732 - sparse_categorical_accuracy: 0.9419
# Epoch 111/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1769 - sparse_categorical_accuracy: 0.9500
# Epoch 112/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1456 - sparse_categorical_accuracy: 0.9599
# Epoch 113/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9608
# Epoch 114/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1383 - sparse_categorical_accuracy: 0.9641
# Epoch 115/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.1775 - sparse_categorical_accuracy: 0.9499
# Epoch 116/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1486 - sparse_categorical_accuracy: 0.9567
# Epoch 117/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1309 - sparse_categorical_accuracy: 0.9634
# Epoch 118/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9630
# Epoch 119/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.1487 - sparse_categorical_accuracy: 0.9603
# Epoch 120/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.1310 - sparse_categorical_accuracy: 0.9552
# Epoch 121/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1604 - sparse_categorical_accuracy: 0.9517
# Epoch 122/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1537 - sparse_categorical_accuracy: 0.9617
# Epoch 123/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1114 - sparse_categorical_accuracy: 0.9780
# Epoch 124/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1086 - sparse_categorical_accuracy: 0.9829
# Epoch 125/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1215 - sparse_categorical_accuracy: 0.9623
# Epoch 126/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1186 - sparse_categorical_accuracy: 0.9698
# Epoch 127/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 0.1368 - sparse_categorical_accuracy: 0.9665
# Epoch 128/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1146 - sparse_categorical_accuracy: 0.9742
# Epoch 129/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1266 - sparse_categorical_accuracy: 0.9760
# Epoch 130/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1200 - sparse_categorical_accuracy: 0.9807
# Epoch 131/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1360 - sparse_categorical_accuracy: 0.9624
# Epoch 132/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1356 - sparse_categorical_accuracy: 0.9681
# Epoch 133/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1140 - sparse_categorical_accuracy: 0.9648
# Epoch 134/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9849
# Epoch 135/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1179 - sparse_categorical_accuracy: 0.9741
# Epoch 136/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 156us/step - loss: 0.1055 - sparse_categorical_accuracy: 0.9797
# Epoch 137/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.1101 - sparse_categorical_accuracy: 0.9836
# Epoch 138/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0967 - sparse_categorical_accuracy: 0.9832
# Epoch 139/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0989 - sparse_categorical_accuracy: 0.9895
# Epoch 140/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1092 - sparse_categorical_accuracy: 0.9817
# Epoch 141/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0992 - sparse_categorical_accuracy: 0.9811
# Epoch 142/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1062 - sparse_categorical_accuracy: 0.9825
# Epoch 143/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9875
# Epoch 144/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9808
# Epoch 145/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9780
# Epoch 146/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1036 - sparse_categorical_accuracy: 0.9840
# Epoch 147/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0974 - sparse_categorical_accuracy: 0.9804
# Epoch 148/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1007 - sparse_categorical_accuracy: 0.9821
# Epoch 149/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0892 - sparse_categorical_accuracy: 0.9872
# Epoch 150/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0770 - sparse_categorical_accuracy: 0.9877
# Epoch 151/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9836
# Epoch 152/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9916
# Epoch 153/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9829
# Epoch 154/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.1003 - sparse_categorical_accuracy: 0.9807
# Epoch 155/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0754 - sparse_categorical_accuracy: 0.9915
# Epoch 156/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9868
# Epoch 157/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0625 - sparse_categorical_accuracy: 0.9919
# Epoch 158/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9894
# Epoch 159/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9817
# Epoch 160/160
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9848

# %%
plt.plot(training_results.history['sparse_categorical_accuracy'])
plt.plot(training_results.history['loss'])
plt.xlabel('epochs')
plt.ylabel('value')
plt.legend(['Sparse Categorical Accuracy', 'Loss'])
plt.grid(True)
plt.show()

ANN.evaluate(X_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0761 - sparse_categorical_accuracy: 0.7732
# [1.145058274269104, 0.7403846383094788]
