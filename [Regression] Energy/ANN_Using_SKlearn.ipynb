# %% [markdown]
# <strong>NOTE:</strong> When the normalizer is adapted on X_train, the loss function decreases much faster than when the normalizer is adapted on all the features.

# %%
import pandas as pd
import tensorflow as tf

dataframe = pd.read_csv("Energy.csv")
dataframe
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
import seaborn as sb
sb.pairplot(data = dataframe, kind = 'scatter', diag_kind = 'kde')

# %%
### Seperate Data
features = dataframe.iloc[:, :-1]
label = dataframe.iloc[:, -1]

# %%
### Split Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features.values, label.values, test_size = 0.3)

# %%
### Standardize Data
from sklearn.preprocessing import StandardScaler
training_scaler = StandardScaler()
testing_scaler = StandardScaler()

X_train = training_scaler.fit_transform(X_train)
X_test = testing_scaler.fit_transform(X_test)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6697, 4), (2871, 4), (6697,), (2871,))

# %%
### Build Model
from keras import Sequential
from keras.layers import InputLayer, Dense
from keras.losses import MeanAbsoluteError
from keras.metrics import MeanSquaredError, R2Score
from keras.optimizers import Adam

ANN = Sequential()
ANN.add( InputLayer( shape = (4,) ) )
ANN.add( Dense( units = 25, activation = "relu" ) )
ANN.add( Dense( units = 25, activation = "relu" ) )
ANN.add( Dense( units = 1 ) )
ANN.compile( optimizer = Adam(), loss = MeanAbsoluteError(), metrics = [MeanSquaredError(), R2Score()])

### Train
ANN.fit( X_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 450.0201 - mean_squared_error: 202881.2969 - r2_score: -698.9742
# Epoch 2/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 345.7374 - mean_squared_error: 126337.7188 - r2_score: -430.6031
# Epoch 3/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 133.7513 - mean_squared_error: 24402.0410 - r2_score: -84.3298
# Epoch 4/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 94.0402 - mean_squared_error: 12720.3223 - r2_score: -42.7667
# Epoch 5/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 51.5687 - mean_squared_error: 4400.1074 - r2_score: -14.2693
# Epoch 6/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.0163 - mean_squared_error: 793.9416 - r2_score: -1.7526
# Epoch 7/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3319 - mean_squared_error: 106.9604 - r2_score: 0.6266
# Epoch 8/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5246 - mean_squared_error: 38.8073 - r2_score: 0.8662
# Epoch 9/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9168 - mean_squared_error: 27.6917 - r2_score: 0.9016
# Epoch 10/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9260 - mean_squared_error: 26.5665 - r2_score: 0.9095
# Epoch 11/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7905 - mean_squared_error: 24.2791 - r2_score: 0.9159
# Epoch 12/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7930 - mean_squared_error: 24.9866 - r2_score: 0.9143
# Epoch 13/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6688 - mean_squared_error: 22.6223 - r2_score: 0.9208
# Epoch 14/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6626 - mean_squared_error: 22.0866 - r2_score: 0.9233
# Epoch 15/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6432 - mean_squared_error: 22.6616 - r2_score: 0.9226
# Epoch 16/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.6642 - mean_squared_error: 22.6766 - r2_score: 0.9213
# Epoch 17/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6296 - mean_squared_error: 22.4480 - r2_score: 0.9217
# Epoch 18/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5030 - mean_squared_error: 20.6859 - r2_score: 0.9280
# Epoch 19/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6598 - mean_squared_error: 21.8733 - r2_score: 0.9255
# Epoch 20/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5582 - mean_squared_error: 20.5148 - r2_score: 0.9291
# Epoch 21/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6217 - mean_squared_error: 21.9571 - r2_score: 0.9239
# Epoch 22/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.5990 - mean_squared_error: 21.4123 - r2_score: 0.9242
# Epoch 23/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.5127 - mean_squared_error: 19.9200 - r2_score: 0.9302
# Epoch 24/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6550 - mean_squared_error: 23.8325 - r2_score: 0.9178
# Epoch 25/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5966 - mean_squared_error: 21.1415 - r2_score: 0.9270
# Epoch 26/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6389 - mean_squared_error: 22.1582 - r2_score: 0.9235
# Epoch 27/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5957 - mean_squared_error: 21.2373 - r2_score: 0.9266
# Epoch 28/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5450 - mean_squared_error: 20.9942 - r2_score: 0.9281
# Epoch 29/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5619 - mean_squared_error: 21.3805 - r2_score: 0.9260
# Epoch 30/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5029 - mean_squared_error: 20.3039 - r2_score: 0.9293
# Epoch 31/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5852 - mean_squared_error: 21.3169 - r2_score: 0.9265
# Epoch 32/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5884 - mean_squared_error: 21.3450 - r2_score: 0.9260
# Epoch 33/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4789 - mean_squared_error: 19.6873 - r2_score: 0.9337
# Epoch 34/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.5437 - mean_squared_error: 20.8411 - r2_score: 0.9285
# Epoch 35/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4949 - mean_squared_error: 19.9841 - r2_score: 0.9307
# Epoch 36/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5178 - mean_squared_error: 20.3628 - r2_score: 0.9303
# Epoch 37/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5483 - mean_squared_error: 20.9992 - r2_score: 0.9286
# Epoch 38/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5478 - mean_squared_error: 20.4045 - r2_score: 0.9287
# Epoch 39/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.5798 - mean_squared_error: 21.2039 - r2_score: 0.9259
# Epoch 40/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5145 - mean_squared_error: 20.2449 - r2_score: 0.9300
# Epoch 41/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5218 - mean_squared_error: 20.0935 - r2_score: 0.9307
# Epoch 42/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5447 - mean_squared_error: 21.3503 - r2_score: 0.9267
# Epoch 43/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4955 - mean_squared_error: 19.9193 - r2_score: 0.9319
# Epoch 44/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5308 - mean_squared_error: 20.4606 - r2_score: 0.9284
# Epoch 45/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4809 - mean_squared_error: 20.2910 - r2_score: 0.9302
# Epoch 46/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5219 - mean_squared_error: 20.3431 - r2_score: 0.9295
# Epoch 47/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4921 - mean_squared_error: 20.7332 - r2_score: 0.9286
# Epoch 48/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5008 - mean_squared_error: 20.4537 - r2_score: 0.9274
# Epoch 49/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5174 - mean_squared_error: 20.1800 - r2_score: 0.9291
# Epoch 50/50
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5291 - mean_squared_error: 21.4609 - r2_score: 0.9254

# %%
### Evaluate
ANN.evaluate(X_test, y_test)
# Out:
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4790 - mean_squared_error: 19.6553 - r2_score: 0.9344
# [3.4559717178344727, 19.52004623413086, 0.9342155456542969]

# %%
from keras.utils import plot_model
plot_model(
  model = ANN, 
  to_file = "model.png", 
  show_shapes = True, 
  show_dtype = True, 
  show_layer_names = True, 
  show_layer_activations = True, 
  show_trainable = True,
  dpi = 100 # size
  )
